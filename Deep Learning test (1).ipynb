# %%
### 1. What does MLP stand for?

a) Multi Linear Processing

b) Multi Layer Perceptron

c) Multi Layered Program

d) Multi Logical Processing

Right option: b- Multli layer perceptron


### 2. What type of neural network is an MLP?
 
a) Convolutional Neural Network

b) Feedforward Neural Network

c) Recurrent Neural Network

d) Radial Neural Network

Right option: Feedforward Neural Network



## 3. What is the purpose of the activation function in MLP?

a) To initialize weights

b) To introduce non-linearity

c) To normalize the input

d) To adjust biases

Right option: To adjust biases 


### 4. Which activation function is commonly used in MLP hidden layers?

a) ReLU

b) Softmax

c) Sigmoid

d) All of the above

Right option - All of the above


### 5. What does the input layer of an MLP do?

a) Produces output predictions

b) Processes data in loops

c) Accepts raw input data

d) Applies activation functions


Right option: Applies activation functions 


### 6. Which algorithm is typically used to train an MLP?

a) Gradient Descent

b) K-Means Clustering

c) Monte Carlo Method

d) Backpropagation

Right option: Backpropagation 


### 7. What are the weights in an MLP?

a) Inputs to the network

b) Connections between neurons

c) Output predictions

d) Training algorithms

Right option: Inputs to the network

### 8. What is the output layer of an MLP used for?

a) Processing hidden units

b) Normalizing the input

c) Providing final predictions

d) Introducing non-linearity


Right option: Providing final predictions


### 9. What type of data does an MLP process?

a) Sequential data

b) Tabular data

c) Image data

d) All of the above

Right option: Image data 

### 10. What is the main drawback of MLPs?

a) Overfitting

b) No learning capacity

c) Limited scalability

d) Lack of generalization

Right option : Limited scalability 


### 11. What is a neuron in an MLP?

a) A single layer in the network

b) A computational unit performing weighted sums and activation

c) A type of input data

d) An algorithm to train the model 

Right option: A computational unit performing weighted sums and activation

### 12. How are the weights in an MLP initialized?

a) Randomly

b) With zeros

c) Based on target output

d) Using fixed values

Right option: Randomly 


### 13. How is overfitting commonly prevented in MLPs?

a) By using a large number of layers

b) By reducing training data

c) By applying regularization (e.g., dropout, L2 norm)

d) By increasing learning rates


Right option: By increasing learning rates


### 14. What is the function of hidden layers in an MLP?

a) To act as the input to the network

b) To learn features from the input data

c) To connect directly to the output

d) To produce random predictions

Right option: To learn features directly from the input data.




### 15. How does the ReLU activation function work?

a) Outputs values between 0 and 1

b) Outputs the same value as the input if it's positive; otherwise 0

c) Outputs values only in negative range

d) Divides the input by 2

Right option: Outputs the same value as the input if its positive otherwise 0.


### 16. What does the Softmax function output?

a) Binary values

b) Probabilities summing to 1

c) Random weights

d) Normalized input data


Right option: Probabilities summing to 1 



### 17. What is the purpose of learning rate in MLP training?

a) To determine the number of layers

b) To adjust the step size for weight updates

c) To initialize the model

d) To reduce the size of the dataset

Right option: To adjust step size for weight updates. 


### 18. How is the loss function used in MLP training?

a) It calculates the weight values

b) It measures the difference between predicted and true outputs

c) It determines the number of hidden layers

d) It defines the learning rate

Right option: It measures the difference between predicted and true outputs 



### 19. Which loss function is commonly used for classification problems in MLPs?

a) Mean Squared Error (MSE)

b) Cross-Entropy Loss

c) Hinge Loss

d) L1 Loss

Right option: Cross -Entropy loss



### 20. What is the main difference between MLP and a single-layer perceptron?

a) MLP has multiple layers of neurons

b) Single-layer perceptron uses backpropagation

c) MLP cannot solve non-linear problems

d) Single-layer perceptron uses ReLU


Right option: MLP has multiple layers of neurons. 



Practical question:

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.18.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (4.0 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /Applications/anaconda3/lib/python3.12/site-packages (from tensorflow) (2.1.0)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-24.12.23-py2.py3-none-any.whl.metadata (876 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /Applications/anaconda3/lib/python3.12/site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Applications/anaconda3/lib/python3.12/site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Applications/anaconda3/lib/python3.12/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /Applications/anaconda3/lib/python3.12/site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /Applications/anaconda3/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-2.5.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Applications/anaconda3/lib/python3.12/site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Applications/anaconda3/lib/python3.12/site-packages (from tensorflow) (1.14.1)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.69.0-cp312-cp312-macosx_10_14_universal2.whl.metadata (3.9 kB)
# Collecting tensorboard<2.19,>=2.18 (from tensorflow)
#   Downloading tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: keras>=3.5.0 in /Applications/anaconda3/lib/python3.12/site-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /Applications/anaconda3/lib/python3.12/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /Applications/anaconda3/lib/python3.12/site-packages (from tensorflow) (3.11.0)
# Collecting ml-dtypes<0.5.0,>=0.4.0 (from tensorflow)
#   Downloading ml_dtypes-0.4.1-cp312-cp312-macosx_10_9_universal2.whl.metadata (20 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Applications/anaconda3/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /Applications/anaconda3/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /Applications/anaconda3/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /Applications/anaconda3/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Applications/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Applications/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Applications/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Applications/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /Applications/anaconda3/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.4.1)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.19,>=2.18->tensorflow)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in /Applications/anaconda3/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Applications/anaconda3/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Applications/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Applications/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /Applications/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)
# Downloading tensorflow-2.18.0-cp312-cp312-macosx_12_0_arm64.whl (239.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.6/239.6 MB 5.9 MB/s eta 0:00:0000:0100:01
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-24.12.23-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.69.0-cp312-cp312-macosx_10_14_universal2.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 6.9 MB/s eta 0:00:0000:0100:01
# Downloading libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 5.5 MB/s eta 0:00:0000:0100:01
# Downloading ml_dtypes-0.4.1-cp312-cp312-macosx_10_9_universal2.whl (405 kB)
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 5.7 MB/s eta 0:00:00a 0:00:01
# Downloading termcolor-2.5.0-py3-none-any.whl (7.8 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Installing collected packages: libclang, flatbuffers, termcolor, tensorboard-data-server, opt-einsum, ml-dtypes, grpcio, google-pasta, gast, astunparse, tensorboard, tensorflow
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml_dtypes 0.5.1
#     Uninstalling ml_dtypes-0.5.1:
#       Successfully uninstalled ml_dtypes-0.5.1
# Successfully installed astunparse-1.6.3 flatbuffers-24.12.23 gast-0.6.0 google-pasta-0.2.0 grpcio-1.69.0 libclang-18.1.1 ml-dtypes-0.4.1 opt-einsum-3.4.0 tensorboard-2.18.0 tensorboard-data-server-0.7.2 tensorflow-2.18.0 termcolor-2.5.0

# %%
import matplotlib.pyplot as plt
from keras.layers import Dense, Flatten
from keras.models import Sequential 
from keras.utils import to_categorical  
from keras.datasets import mnist

import warnings
warnings.filterwarnings('ignore')

# %%
from keras.datasets import mnist

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
print(y_test.shape)
# Out:
# (10000,)

# %%
print(x_train.shape)
# Out:
# (60000, 28, 28)

# %%
fig,axes=plt.subplots(ncols=10,sharex=False,sharey=True,figsize=(20,4))
axes[i].set_title(y_train[i])
axes[i].imshow(x_train[i],cmap='gray')
axes[i].get_xaxis().set_visible(False)
axes[i].get_yaxis().set_visible(False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 2
#       1 fig,axes=plt.subplots(ncols=10,sharex=False,sharey=True,figsize=(20,4))
# ----> 2 axes[i].set_title(y_train[i])
#       3 axes[i].imshow(x_train[i],cmap='gray')
#       4 axes[i].get_xaxis().set_visible(False)
#
# NameError: name 'i' is not defined
